# %% [markdown]
# Project Objective
# The goal of this project is to analyze supermarket sales data to understand customer behavior, product performance, branch-wise revenue, payment preferences, and business growth opportunities.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customer=pd.read_csv("SUPER-1.csv")

# %%
customer.rename(columns={
    'Row Labels':'product_line',
    'Sum of Sum of Total_Quantity':'total_quantity',
    'Sum of Sum of Average_Sales':'average_sales'
}, inplace=True)

# %%
customer
# Out:
#              product_line  total_quantity  average_sales
# 0  Electronic accessories             971     319.632538
# 1     Fashion accessories             902     305.089298
# 2      Food and beverages             952     322.671517
# 3       Health and beauty             854     323.643020
# 4      Home and lifestyle             911     336.636956
# 5       Sports and travel             920     332.065220
# 6             Grand Total            5510    1939.738549

# %%
standard_deviation=customer["total_quantity"].std()
standard_deviation
# Out:
# 1735.8886978803023

# %%
mean=customer["total_quantity"].mean()
mean
# Out:
# np.float64(1574.2857142857142)

# %%
customer.corr(numeric_only=True)
# Out:
#                               Sum of Sum of Total_Quantity  \
# Sum of Sum of Total_Quantity                      1.000000
# Sum of Sum of Average_Sales                       0.999631
#
#                               Sum of Sum of Average_Sales
# Sum of Sum of Total_Quantity                     0.999631
# Sum of Sum of Average_Sales                      1.000000

# %%
branch=pd.read_csv("SUPER-2.csv")
branch
# Out:
#         branch  Sum of Total_Quantity  Sum of Average_Sales
# 0         Alex                   1859            312.354031
# 1        Cairo                   1820            319.872506
# 2         Giza                   1831            337.099715
# 3  Grand Total                   5510            969.326252

# %%
branch.rename(columns={'Sum of Total_Quantity':"Total_Quantity",
                       "Sum of Average_Sales":"Total_Sales"},inplace=True)

# %%
branch.corr(numeric_only=True)
# Out:
#                 Total_Quantity  Total_Sales
# Total_Quantity        1.000000     0.999298
# Total_Sales           0.999298     1.000000

# %%
plt.figure(figsize=(5,8))
sns.heatmap(branch.corr(numeric_only=True),annot=True)
plt.title("CORRELATION HEATMAP")

plt.show()

# %%
customer.rename(columns={
    'Row Labels':'product_line',
    'Sum of Sum of Total_Quantity':'total_quantity',
    'Sum of Sum of Average_Sales':'average_sales'
}, inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

sns.boxplot(x=customer['total_quantity'])

plt.title("Outlier Detection")

plt.show()

# %%
payment=pd.read_csv("SUPER-3.csv")
# Out:
#        Payment  Sum of Total_Transactions  Sum of Average_Unit_price
# 0         Cash                        344                  56.758983
# 1  Credit card                        311                  54.394469
# 2      Ewallet                        345                  55.740174
# 3  Grand Total                       1000                 166.893626

# %%
payment.rename(columns={'Sum of Total_Transactions':'Total_Transactions',
                       'Sum of Average_Unit_price':'Total_Unit_Price'} ,inplace=True)

# %%
payment
# Out:
#        Payment  Total_Transactions  Total_Unit_Price
# 0         Cash                 344         56.758983
# 1  Credit card                 311         54.394469
# 2      Ewallet                 345         55.740174
# 3  Grand Total                1000        166.893626

# %%
corr=payment.corr(numeric_only=True)
corr
# Out:
#                     Total_Transactions  Total_Unit_Price
# Total_Transactions            1.000000          0.999462
# Total_Unit_Price              0.999462          1.000000

# %%
plt.figure(figsize=(8,5))
sns.heatmap(corr,annot=True)
plt.title("correlation heatmap")

plt.show()

# %%
sns.boxplot(x=payment["Total_Transactions"])

plt.title("Outlier Detection")

plt.show()

# %%
city=pd.read_csv("SUPER-4.csv")
city
# Out:
#         city  GENDER_COUNT  CUSTOMER_TYPE_COUNT
# 0     Yangon           340                  340
# 1  Naypyitaw           328                  328
# 2   Mandalay           332                  332

# %%
corr=city.corr(numeric_only=True)
corr
# Out:
#                      GENDER_COUNT  CUSTOMER_TYPE_COUNT
# GENDER_COUNT                  1.0                  1.0
# CUSTOMER_TYPE_COUNT           1.0                  1.0

# %%
sns.heatmap(corr,annot=True,cmap="YlGnBu")
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.boxplot(x=city['GENDER_COUNT'])
plt.title("Outlier Detection")
plt.show()

# %%
final=pd.read_csv("SUPER-5.csv")
final
# Out:
#    gender  Average_Sales
# 0  Female     340.931414
# 1    Male     299.055738

# %%
corr=final.corr(numeric_only=True)
corr
# Out:
#                Average_Sales
# Average_Sales            1.0

# %%
count = final["gender"].value_counts()

plt.bar(count.index, count.values)
plt.title("Gender Count")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# CONCLUDING ANSWERS:
#
#
# Which product line generates the highest revenue?
#
# Home and Lifestyle has the highest average sales: 336.64.
#
# Which branch performs best?
#
# Giza performs best with the highest average sales: 337.10.
#
# Which city has the highest customer activity?
#
# Yangon has the highest customer activity with 340 customers.
#
# Which payment method is most preferred?
#
# Ewallet is most preferred with 345 transactions, slightly higher than Cash.
#
# Do male and female customers spend differently?
#
# Yes. Female customers spend more on average:
# Female: 340.93
#
# Male: 299.06
#
# Which product line has the highest average sales?
#
# Home and Lifestyle has the highest average sales: 336.64.
#
# What recommendations can improve supermarket performance?
#
# Increase stock and promotions for Home and Lifestyle.
#
# Improve weak categories like Fashion Accessories.
#
# Focus more on Giza branch, since it performs best.
#
# Promote Ewallet payments, as customers use it most.
#
# Target female customers with premium offers because they spend more on average.
